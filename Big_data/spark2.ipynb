# %% [markdown]
# <a href="https://colab.research.google.com/github/adas754/Big_data/blob/main/spark2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
#start the spark session
spark=SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://2c11193d8013:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
df_pyspark.show(3)
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# +--------+---+----------+------+
# only showing top 3 rows

# %%
### Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Ben', age=31, Experience=10, Salary=30000),
#  Row(Name='Srikanth', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %% [markdown]
# ### Selecting Columns And Indexing

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
#Selecting single column
df_pyspark.select('Name').show()
# Out:
# +--------+
# |    Name|
# +--------+
# |     Ben|
# |Srikanth|
# |   Sunny|
# |    Paul|
# |  Harish|
# |   Shiva|
# +--------+

# %%
#selecting multiple columns
df_pyspark.select(['Name','Experience']).show()
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# |    Paul|         3|
# |  Harish|         1|
# |   Shiva|         2|
# +--------+----------+

# %%
ord('B') # 66
ord('S') # 83
ord('P') # 80
ord('r') #114
ord('u') #117
ord('h') #104
# Out:
# 104

# %%
df_pyspark.filter(df_pyspark['Name'] == 'Paul').show()
# Out:
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# +----+---+----------+------+
# |Paul| 24|         3| 20000|
# +----+---+----------+------+

# %%
#Slicing wont work
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %% [markdown]
# ### Check Describe option similar to Pandas

# %%
df_pyspark.describe().show()
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
### Adding Columns in data frame
df_pyspark=df_pyspark.withColumn('Experience After 2 year',
                                 df_pyspark['Experience']+2)

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+-----------------------+
# |    Name|age|Experience|Salary|Experience After 2 year|
# +--------+---+----------+------+-----------------------+
# |     Ben| 31|        10| 30000|                     12|
# |Srikanth| 30|         8| 25000|                     10|
# |   Sunny| 29|         4| 20000|                      6|
# |    Paul| 24|         3| 20000|                      5|
# |  Harish| 21|         1| 15000|                      3|
# |   Shiva| 23|         2| 18000|                      4|
# +--------+---+----------+------+-----------------------+

# %%
### Drop the columnsl
df_pyspark=df_pyspark.drop('Experience After 2 year')

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
### Rename the columns
df_pyspark.withColumnRenamed('Name','New_Name').show()
# Out:
# +--------+---+----------+------+
# |New_Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+
